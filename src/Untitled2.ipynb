# %%
import numpy.random as rnd
import numpy as np

# %%
a = rnd.randint(0,2,1)

# %%
a.item()
# Out:
# 1

# %%
ac = np.load('npy/action0.npy')
st = np.load('npy/state0.npy')

# %%
ac.shape
# Out:
# (200, 14)

# %%
m = np.zeros([200,14])+np.arange(200).reshape(-1,1)

# %%
m[ac==-100].min()
# Out:
# 12.0

# %%
i = 0
for t, a in enumerate(ac):
    if -100 in a:
        print(i, st[t:t+2,a==-100])
    i += 1
# Out:
# 12 [[[ 0.09792677  1.2102052  -0.24241513 -2.1078155 ]
#   [ 0.1929023   1.1714939  -0.23272254 -1.9708769 ]]
#
#  [[ 0.          0.          0.          0.        ]
#   [ 0.          0.          0.          0.        ]]]
# 13 [[[ 0.          0.          0.          0.        ]
#   [ 0.          0.          0.          0.        ]
#   [ 0.14069107  1.3518615  -0.2196501  -2.3237474 ]]
#
#  [[ 0.          0.          0.          0.        ]
#   [ 0.          0.          0.          0.        ]
#   [ 0.14069107  1.3518615  -0.2196501  -2.3237474 ]]]
# 14 [[[ 0.          0.          0.          0.        ]
#   [ 0.          0.          0.          0.        ]
#   [ 0.14069107  1.3518615  -0.2196501  -2.3237474 ]]
#
#  [[ 0.          0.          0.          0.        ]
#   [ 0.          0.          0.          0.        ]
#   [ 0.09840678  0.9588549  -0.1470988  -1.6464504 ]]]
# 15 [[[ 0.          0.          0.          0.        ]
#   [-0.15015219 -0.65009016  0.22641416  1.2224832 ]
# ...

# %%
t = 50
a = ac[t]
False in (a!=-100), a[a!=-100].sum()
# Out:
# (True, 0)
